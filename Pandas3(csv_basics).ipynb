# %%
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Nikhil Gupta\ML_Pandas

# %%
dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv')
dfs
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
pd.DataFrame(pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\Top-10-IT-Companies-in-India.csv'))
# Out:
#   Top 10 IT Companies in India
# 0                          TCS
# 1                      Infosys
# 2                Tech Mahindra
# 3                        Wipro
# 4             HCL Technologies
# 5                 L&T Infotech
# 6                     Mindtree
# 7                      Mphasis
# 8    Oracle Financial Services
# 9                  Rotla India

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Nikhil Gupta\ML_Pandas

# %%
dfs.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeping hrs',
#        'Social Media usage hrs', 'Mobile Games hrs', 'Percantege'],
#       dtype='object')

# %%
dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv', nrows =1)
dfs
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
#
#    Mobile Games hrs  Percantege
# 0                 5          50

# %%
dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv', nrows =5)
dfs
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv',usecols =[0])
dfs
# Out:
#    Student ID
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
# 5        1006
# 6        1007
# 7        1008
# 8        1009
# 9        1010

# %%
dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv',usecols =[0,1,2])
dfs
# Out:
#    Student ID  Class  Study hrs
# 0        1001     10          2
# 1        1002     10          6
# 2        1003     10          3
# 3        1004     11          0
# 4        1005     11          4
# 5        1006     11         10
# 6        1007     12          4
# 7        1008     12         10
# 8        1009     12          2
# 9        1010     12          6

# %%
 dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv',skiprows =2)
dfs
# Out:
#    1002  10   6   8  2  0  80
# 0  1003  10   3   8  2  4  60
# 1  1004  11   0  10  1  5  45
# 2  1005  11   4   7  2  0  75
# 3  1006  11  10   7  0  0  96
# 4  1007  12   4   6  0  0  80
# 5  1008  12  10   6  2  0  90
# 6  1009  12   2   8  2  4  60
# 7  1010  12   6   9  1  0  85

# %%
 dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv',skiprows =[1])
dfs
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1002     10          6             8                       2
# 1        1003     10          3             8                       2
# 2        1004     11          0            10                       1
# 3        1005     11          4             7                       2
# 4        1006     11         10             7                       0
# 5        1007     12          4             6                       0
# 6        1008     12         10             6                       2
# 7        1009     12          2             8                       2
# 8        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 0          80
# 1                 4          60
# 2                 5          45
# 3                 0          75
# 4                 0          96
# 5                 0          80
# 6                 0          90
# ...

# %%
 dfs =pd.read_csv('C:\\Users\\Nikhil Gupta\\ML_Pandas\\student_results.csv',skiprows =[2,3,4])
dfs
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1005     11          4             7                       2
# 2        1006     11         10             7                       0
# 3        1007     12          4             6                       0
# 4        1008     12         10             6                       2
# 5        1009     12          2             8                       2
# 6        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          75
# 2                 0          96
# 3                 0          80
# 4                 0          90
# 5                 4          60
# 6                 0          85
